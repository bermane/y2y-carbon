# %% [markdown]
# ## Load packages and initialize GEE

# %%
# import packages
import ee
import geemap
import pandas as pd

# %%
# authenticate the EE api
# ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# initialize the EE api
ee.Initialize(project='ee-bermane')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # initialize the EE api
# ----> 2 ee.Initialize(project='ee-bermane')
#
# File ~/Team Braintree Dropbox/Ethan Berman/Python Projects/y2y-carbon/.venv/lib/python3.12/site-packages/ee/_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File ~/Team Braintree Dropbox/Ethan Berman/Python Projects/y2y-carbon/.venv/lib/python3.12/site-packages/ee/__init__.py:154, in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     137 """Initialize the EE library.
#     138
#     139 If this hasn't been called by the time any object constructor is used,
#    (...)
#     151   project: The client project ID or number to use when making API calls.
#     152 """
#     153 if credentials == 'persistent':
# --> 154   credentials = data.get_persistent_credentials()
#     155 if not project and credentials and hasattr(credentials, 'quota_project_id'):
#     156   project = credentials.quota_project_id
#
# File ~/Team Braintree Dropbox/Ethan Berman/Python Projects/y2y-carbon/.venv/lib/python3.12/site-packages/ee/data.py:281, in get_persistent_credentials()
#     279   if oauth.is_valid_credentials(credentials):
#     280     return credentials
# --> 281 raise ee_exception.EEException(  # pylint: disable=raise-missing-from
#     282     'Please authorize access to your Earth Engine account by '
#     283     'running\n\nearthengine authenticate\n\n'
#     284     'in your command line, or ee.Authenticate() in Python, and then retry.'
#     285 )
#
# EEException: Please authorize access to your Earth Engine account by running
#
# earthengine authenticate
#
# in your command line, or ee.Authenticate() in Python, and then retry.

# %% [markdown]
# ## Define GEE datasets

# %%
# define EE datasets
# biomass
agb = ee.ImageCollection("projects/sat-io/open-datasets/ESA/ESA_CCI_AGB")
rsr = ee.Image("projects/ee-bermane/assets/Root_shoot_ratio_Map_Merged")

# soc
soc_olm = ee.Image("projects/ee-bermane/assets/soc_0_1m_kg_m2_olm")
soc_sothe = ee.Image(
    "projects/ee-bermane/assets/McMaster_WWFCanada_soil_carbon1m_250m_kg-m2_version3")
soc_0_10_olm_global = ee.Image(
    "projects/ee-bermane/assets/soc_0_10cm_kg_m2_olm_global")
soc_10_30_olm_global = ee.Image(
    "projects/ee-bermane/assets/soc_10_30cm_kg_m2_olm_global")
soc_30_60_olm_global = ee.Image(
    "projects/ee-bermane/assets/soc_30_60cm_kg_m2_olm_global")
soc_60_100_olm_global = ee.Image(
    "projects/ee-bermane/assets/soc_60_100cm_kg_m2_olm_global")

# peatlands
peat = ee.Image("projects/sat-io/open-datasets/GLOBAL-PEATLAND-DATABASE")

# landcover
lc = ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS")
wte = ee.Image("projects/ee-bermane/assets/WTE_2020")
k1 = ee.Image("projects/ee-bermane/assets/k1_global")

# netflux
netflux = ee.ImageCollection(
    "projects/wri-datalab/gfw-data-lake/net-flux-forest-extent-per-ha-v1-3-2-2001-2023/net-flux-global-forest-extent-per-ha-2001-2023"
)

# irrecoverable carbon (Noon layers)
irr_carbon_biomass = ee.Image("projects/sat-io/open-datasets/irrecoverable_carbon/carbon_biomass/carbon_biomass_2018")
irr_carbon_soc = ee.Image("projects/sat-io/open-datasets/irrecoverable_carbon/carbon_soil/carbon_soil_2018")
irr_carbon_total = ee.Image("projects/sat-io/open-datasets/irrecoverable_carbon/carbon_total/carbon_total_2018")

# vector
y2y = ee.FeatureCollection("projects/ee-bermane/assets/y2y")
y2y_ecoregions = ee.FeatureCollection(
    "projects/ee-bermane/assets/y2y_ecoregions")
y2y_biomes = ee.FeatureCollection("projects/ee-bermane/assets/y2y_biomes")
rra = ee.FeatureCollection("projects/ee-bermane/assets/ross_river_ipca")
countries = ee.FeatureCollection("USDOS/LSIB/2017")
y2y_protected_areas = ee.FeatureCollection(
    "projects/ee-bermane/assets/y2y_protected_areas")
y2y_protected_areas_canada = ee.FeatureCollection(
    "projects/ee-bermane/assets/y2y_protected_areas_canada")
us_can = ee.FeatureCollection("projects/ee-bermane/assets/us_can_simple")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Calculate north america biomass

# %%
# calc 2021 ESA CCI biomass
# grab the 2021 AGB images
agb_2021 = agb.filter(ee.Filter.stringContains("system:index", "2021")).first()

# create image for litter using Harris ratio (4%)
# leave out dead wood since it is likely sensed already
# mask litter only for forested LC types
# 1: "#033e00",  # Temperate or sub-polar needleleaf forest
# 2: "#939b71",  # Sub-polar taiga needleleaf forest
# 3: "#196d12",  # Tropical or sub-tropical broadleaf evergreen forest
# 4: "#1fab01",  # Tropical or sub-tropical broadleaf deciduous forest
# 5: "#5b725c",  # Temperate or sub-polar broadleaf deciduous forest
# 6: "#6b7d2c",  # Mixed forest

litter_mask = lc.gte(1).And(lc.lte(6))

litter = agb_2021.select(['AGB']).multiply(0.04).multiply(litter_mask)

# create image for BGB (using global rsr map)
bgb = agb_2021.select(['AGB']).multiply(rsr).rename('BGB')

# add AGB + litter and BGB together
bio_2021 = agb_2021.select(['AGB']).add(litter).addBands(
    bgb).rename(['agb_t_ha', 'bgb_t_ha'])

# multiply values by 0.47 to get carbon density
# 0.47 used by Harris et al. (2021)
# mask water (18) and snow/ice (19)
bio_2021 = bio_2021.multiply(0.47).updateMask(
    lc.neq(18).And(lc.neq(19)))

# compute per-pixel area in ha
pixel_area_ha = ee.Image.pixelArea().divide(10000)

# Create carbon layer mask to filter pixel area raster
carbon_mask = bio_2021.select(['agb_t_ha']).mask().neq(0)

# Mask pixel_area_ha to carbon layers
pixel_area_agb_extent = pixel_area_ha.updateMask(carbon_mask)

# calculate total biomass c per pixel and rename bands
bio_stock_2021 = bio_2021.multiply(
    pixel_area_ha
).rename(
    ['agb_t', 'bgb_t']
).addBands(
    pixel_area_agb_extent.rename(['pixel_area_agb_extent_ha'])
).addBands(
    pixel_area_ha.rename(['pixel_area_ha'])
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# # export bio_2021 raster to drive
# ee.batch.Export.image.toDrive(
#     image=bio_2021.select(['agb_t_ha']),
#     description='bio_2021',
#     region=y2y.geometry(),
#     scale=30,
#     maxPixels=1e13,
#     fileNamePrefix='bio_2021'
# ).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Calculate soil carbon from Sothe Canada data and Open Land Map US data

# %%
# calc open land map soc
# add the layers together from 0-100cm
soc_olm = (
    soc_0_10_olm_global
    .add(soc_10_30_olm_global)
    .add(soc_30_60_olm_global)
    .add(soc_60_100_olm_global)
    )

# multiply by 10 to get t/ha
# mask water/snow/ice
soc_olm = soc_olm.multiply(10).rename(
    'soc_dens').updateMask(lc.neq(18).And(lc.neq(19)))

# reproject to match sothe to blend images
soc_olm_reproj_sothe = soc_olm.resample('bilinear').toFloat()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# calc sothe soc
# multiply by 10 to get t/ha)
# mask water/snow/ice
soc_sothe = soc_sothe.multiply(10).rename(
    'soc_dens').updateMask(lc.neq(18).And(lc.neq(19)))

# blend sothe and olm carbon across y2y
soc_blend = ee.ImageCollection([soc_olm_reproj_sothe, soc_sothe]).mosaic().rename('soc_t_ha').reproject(
    crs=soc_sothe.projection(),
    crsTransform=soc_sothe.projection().getInfo().get('transform')
).updateMask(lc.neq(18).And(lc.neq(19)))  # mask snow/ice, water

# Create soc layer mask to filter pixel area raster
soc_mask = soc_blend.mask().neq(0)

# Mask pixel_area_ha to carbon layers
pixel_area_soc_extent = pixel_area_ha.updateMask(soc_mask)

# multiply by pixel area to get total carbon per pixel
soc_blend_stock = soc_blend.multiply(pixel_area_ha).rename('soc_t').addBands(
    pixel_area_soc_extent.rename(['pixel_area_soc_extent_ha'])
).addBands(
    pixel_area_ha.rename(['pixel_area_ha'])
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Calculate average carbon density in mountains vs. non-mountains in US and Canada combined
#
# do I need to mask for values >0 as well to make sure we are fairly counting where there is actually biomass??? or is that already done?

# %%
# clip data to us/canada feature collection
# since us/canada is big and complex image collection
bio_2021_us_can = bio_2021.clipToCollection(us_can)
soc_blend_us_can = soc_blend.clipToCollection(us_can)

# define geometry bigger than us/canada
big_geo = ee.Geometry.Rectangle(
    coords=[171, 18, 308, 84],
    proj=ee.Projection('EPSG:4326'),  # Explicitly defining the projection
    geodesic=False)

# # Create a Feature with this geometry
# big_feature = ee.Feature(big_geo, {"name": "Bigger than US/CAN"})

# # Create a FeatureCollection
# big_fc = ee.FeatureCollection([big_feature])

# mask biomass with k1 mountain layer
# reduce to single image
biomass_k1 = (
    bio_2021_us_can
    .updateMask(k1) # mask for mountains only
    .reduce(ee.Reducer.sum()) # sum biomass layers
    .rename(['bio_t_ha'])
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=big_geo,
        scale=bio_2021_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask biomass with not k1 mountain layer
# reduce to single image
biomass_not_k1 = (
    bio_2021_us_can
    .updateMask(k1.Not()) # mask for not mountains
    .reduce(ee.Reducer.sum()) # sum biomass layers
    .rename(['bio_t_ha'])
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=big_geo,
        scale=bio_2021_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask soc with k1 mountain layer
soc_k1 = (
    soc_blend_us_can
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=big_geo,
        scale=soc_blend_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask soc with not k1 mountain layer
soc_not_k1 = (
    soc_blend_us_can
    .updateMask(k1.Not()) # mask for not mountains
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=big_geo,
        scale=soc_blend_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "biomass_k1": biomass_k1,
            "biomass_not_k1": biomass_not_k1,
            "soc_k1": soc_k1, 
            "soc_not_k1": soc_not_k1
            })]),
    description="carbon_density_k1_stats_us_can",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# do the same for total carbon stock
biomass_k1 = (
    bio_2021_us_can.multiply(pixel_area_ha)
    .updateMask(k1) # mask for mountains only
    .reduce(ee.Reducer.sum()) # sum biomass layers
    .rename(['bio_t_ha'])
    .reduceRegion( # calc sum
        reducer=ee.Reducer.sum(),
        geometry=big_geo,
        scale=bio_2021_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

biomass_not_k1 = (
    bio_2021_us_can.multiply(pixel_area_ha)
    .updateMask(k1.Not()) # mask for not mountains
    .reduce(ee.Reducer.sum()) # sum biomass layers
    .rename(['bio_t_ha'])
    .reduceRegion( # calc sum
        reducer=ee.Reducer.sum(),
        geometry=big_geo,
        scale=bio_2021_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

soc_k1 = (
    soc_blend_us_can.multiply(pixel_area_ha)
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc sum
        reducer=ee.Reducer.sum(),
        geometry=big_geo,
        scale=soc_blend_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

soc_not_k1 = (
    soc_blend_us_can.multiply(pixel_area_ha)
    .updateMask(k1.Not()) # mask for not mountains
    .reduceRegion( # calc sum
        reducer=ee.Reducer.sum(),
        geometry=big_geo,
        scale=soc_blend_us_can.projection().nominalScale(),
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "biomass_k1": biomass_k1,
            "biomass_not_k1": biomass_not_k1,
            "soc_k1": soc_k1, 
            "soc_not_k1": soc_not_k1
            })]),
    description="carbon_stock_k1_stats_us_can",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# mask biomass for Y2Y only
biomass_y2y = (
    bio_2021
    .reduce(ee.Reducer.sum()) # sum biomass layers
    .rename(['bio_t_ha'])
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=y2y.geometry(),
        scale=bio_2021.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask soc for Y2Y only
soc_y2y = (
    soc_blend
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=y2y.geometry(),
        scale=soc_blend.projection().nominalScale(),
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "biomass_y2y": biomass_y2y,
            "soc_y2y": soc_y2y
            })]),
    description="carbon_density_stats_y2y",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# do the same for total carbon stock
biomass_y2y = (
    bio_2021.multiply(pixel_area_ha)
    .reduce(ee.Reducer.sum()) # sum biomass layers
    .rename(['bio_t_ha'])
    .reduceRegion( # calc sum
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=bio_2021.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask soc for Y2Y only
soc_y2y = (
    soc_blend.multiply(pixel_area_ha)
    .reduceRegion( # calc sum
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=soc_blend.projection().nominalScale(),
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "biomass_y2y": biomass_y2y,
            "soc_y2y": soc_y2y
            })]),
    description="carbon_stock_stats_y2y",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Calculate irrecoverable carbon in mountains (Noon Layers)

# %%
# create a global geometry to reduce over
globe = ee.Geometry.Rectangle(
    coords=[-180, -89, 180, 89],
    proj=ee.Projection('EPSG:4326'),  # Explicitly defining the projection,
    geodesic=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# carbon density 2018
# mask irr_carbon_biomass with k1 mountain layer
irr_carbon_biomass_k1 = (
    irr_carbon_biomass
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=globe,
        scale=irr_carbon_biomass.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_biomass with not k1 mountain layer
irr_carbon_biomass_not_k1 = (
    irr_carbon_biomass
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=globe,
        scale=irr_carbon_biomass.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_biomass with y2y
irr_carbon_biomass_y2y = (
    irr_carbon_biomass
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=y2y.geometry(),
        scale=irr_carbon_biomass.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_soc with k1 mountain layer
irr_carbon_soc_k1 = (
    irr_carbon_soc
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=globe,
        scale=irr_carbon_soc.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_soc with not k1 mountain layer
irr_carbon_soc_not_k1 = (
    irr_carbon_soc
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=globe,
        scale=irr_carbon_soc.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_soc with y2y
irr_carbon_soc_y2y = (
    irr_carbon_soc
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=y2y.geometry(),
        scale=irr_carbon_soc.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_total with k1 mountain layer
irr_carbon_total_k1 = (
    irr_carbon_total
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=globe,
        scale=irr_carbon_total.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_total with not k1 mountain layer
irr_carbon_total_not_k1 = (
    irr_carbon_total
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=globe,
        scale=irr_carbon_total.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_total with y2y
irr_carbon_total_y2y = (
    irr_carbon_total
    .reduceRegion( # calc mean density
        reducer=ee.Reducer.mean(),
        geometry=y2y.geometry(),
        scale=irr_carbon_total.projection().nominalScale(),
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "irr_carbon_biomass_k1": irr_carbon_biomass_k1,
            "irr_carbon_biomass_not_k1": irr_carbon_biomass_not_k1,
            "irr_carbon_biomass_y2y": irr_carbon_biomass_y2y,
            "irr_carbon_soc_k1": irr_carbon_soc_k1,
            "irr_carbon_soc_not_k1": irr_carbon_soc_not_k1,
            "irr_carbon_soc_y2y": irr_carbon_soc_y2y,
            "irr_carbon_total_k1": irr_carbon_total_k1,
            "irr_carbon_total_not_k1": irr_carbon_total_not_k1,
            "irr_carbon_total_y2y": irr_carbon_total_y2y
            })]),
    description="noon_global_irr_carbon_density_k1_stats",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# do the same for total carbon
# can use the same pixel_area_ha since irrecoverable carbon
# layers are also in ha

# mask irr_carbon_biomass with k1 mountain layer
irr_carbon_biomass_k1 = (
    irr_carbon_biomass.multiply(pixel_area_ha)
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=globe,
        scale=irr_carbon_biomass.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_biomass with not k1 mountain layer
irr_carbon_biomass_not_k1 = (
    irr_carbon_biomass.multiply(pixel_area_ha)
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=globe,
        scale=irr_carbon_biomass.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_biomass with y2y
irr_carbon_biomass_y2y = (
    irr_carbon_biomass.multiply(pixel_area_ha)
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=irr_carbon_biomass.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_soc with k1 mountain layer
irr_carbon_soc_k1 = (
    irr_carbon_soc.multiply(pixel_area_ha)
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=globe,
        scale=irr_carbon_soc.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_soc with not k1 mountain layer
irr_carbon_soc_not_k1 = (
    irr_carbon_soc.multiply(pixel_area_ha)
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=globe,
        scale=irr_carbon_soc.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_soc with y2y
irr_carbon_soc_y2y = (
    irr_carbon_soc.multiply(pixel_area_ha)
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=irr_carbon_soc.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_total with k1 mountain layer
irr_carbon_total_k1 = (
    irr_carbon_total.multiply(pixel_area_ha)
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=globe,
        scale=irr_carbon_total.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_total with not k1 mountain layer
irr_carbon_total_not_k1 = (
    irr_carbon_total.multiply(pixel_area_ha)
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=globe,
        scale=irr_carbon_total.projection().nominalScale(),
        maxPixels=1e20
    )
)

# mask irr_carbon_total with y2y
irr_carbon_total_y2y = (
    irr_carbon_total.multiply(pixel_area_ha)
    .reduceRegion( # calc total stock
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=irr_carbon_total.projection().nominalScale(),
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "irr_carbon_biomass_k1": irr_carbon_biomass_k1,
            "irr_carbon_biomass_not_k1": irr_carbon_biomass_not_k1,
            "irr_carbon_biomass_y2y": irr_carbon_biomass_y2y,
            "irr_carbon_soc_k1": irr_carbon_soc_k1,
            "irr_carbon_soc_not_k1": irr_carbon_soc_not_k1,
            "irr_carbon_soc_y2y": irr_carbon_soc_y2y,
            "irr_carbon_total_k1": irr_carbon_total_k1,
            "irr_carbon_total_not_k1": irr_carbon_total_not_k1,
            "irr_carbon_total_y2y": irr_carbon_total_y2y
            })]),
    description="noon_global_irr_carbon_stock_k1_stats",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## General Area Stats

# %%
# Y2Y in K1
y2y_k1 = (
    pixel_area_ha
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc total ha
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=100,
        maxPixels=1e20
    )
)

# Y2Y not in K1
y2y_not_k1 = (
    pixel_area_ha
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc total ha
        reducer=ee.Reducer.sum(),
        geometry=y2y.geometry(),
        scale=100,
        maxPixels=1e20
    )
)

print(y2y_k1.getInfo())
print(y2y_not_k1.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'area': 117872727.48829964}
# {'area': 19122206.87470022}

# %%
# US/CAN in K1
us_can_k1 = (
    pixel_area_ha
    .clipToCollection(us_can)
    .updateMask(k1) # mask for mountains only
    .reduceRegion( # calc total ha
        reducer=ee.Reducer.sum(),
        geometry=big_geo,
        scale=100,
        maxPixels=1e20
    )
)

# US/CAN not in K1
us_can_not_k1 = (
    pixel_area_ha
    .clipToCollection(us_can)
    .updateMask(k1.Not()) # mask for not mountains only
    .reduceRegion( # calc total ha
        reducer=ee.Reducer.sum(),
        geometry=big_geo,
        scale=100,
        maxPixels=1e20
    )
)

# export to drive
ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection([
        ee.Feature(None, {
            "us_can_k1": us_can_k1,
            "us_can_not_k1": us_can_not_k1
            })]),
    description="us_can_k1_area_stats",
    folder="",
    fileFormat="CSV"
).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Add layers to map

# %%
# set biomass palette
biomass_palette = [
    "#C6ECAE", "#A1D490", "#7CB970", "#57A751", "#348E32",
    "#267A29", "#176520", "#0C4E15", "#07320D", "#031807"
]

# set land cover palette
lc_palette = [
    "#033e00",  # Temperate or sub-polar needleleaf forest
    "#939b71",  # Sub-polar taiga needleleaf forest
    "#196d12",  # Tropical or sub-tropical broadleaf evergreen forest
    "#1fab01",  # Tropical or sub-tropical broadleaf deciduous forest
    "#5b725c",  # Temperate or sub-polar broadleaf deciduous forest
    "#6b7d2c",  # Mixed forest
    "#b29d29",  # Tropical or sub-tropical shrubland
    "#b48833",  # Temperate or sub-polar shrubland
    "#e9da5d",  # Tropical or sub-tropical grassland
    "#e0cd88",  # Temperate or sub-polar grassland
    "#a07451",  # Sub-polar or polar shrubland-lichen-moss
    "#bad292",  # Sub-polar or polar grassland-lichen-moss
    "#3f8970",  # Sub-polar or polar barren-lichen-moss
    "#6ca289",  # Wetland
    "#e6ad6a",  # Cropland
    "#a9abae",  # Barren land
    "#db2126",  # Urban and built-up
    "#4c73a1",  # Water
    "#fff7fe",  # Snow and ice
]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# create a map
m = geemap.Map()

# add layers
# m.addLayer(soc_blend, {"min": 1, "max": 450, "palette": biomass_palette}, "SOC Density Blend 0-1m")
# m.addLayer(soc_olm_reproj_sothe, {"min": 1, "max": 450, "palette": biomass_palette}, "SOC OLM Density 0-1m")
# m.addLayer(soc_sothe, {"min": 1, "max": 450, "palette": biomass_palette}, "SOC Sothe Density 0-1m")
# m.addLayer(rsr, {}, 'Root-to-Shoot Ratio Global')
# m.addLayer(bio_2021.select(['agb_t_ha']).clip(y2y), {
#           "min": 1, "max": 100, "palette": biomass_palette}, 'CCI AGB Density')
# m.addLayer(bio_2021.select(['dpm_t_ha']).clip(y2y), {"min": 1, "max": 60, "palette": biomass_palette}, 'DPM Density')
# m.addLayer(pixel_area_agb_extent.clip(y2y), {}, 'Carbon Mask')
# m.addLayer(lc, {"min": 1, "max": 19,
#                 "palette": lc_palette}, 'Landcover')
# m.addLayer(lc.mask(), {}, 'LC Mask')
# m.addLayer(y2y_can, {}, 'Y2Y Canada Extent')
# m.addLayer(big_fc, {}, 'Big Geo')
# m.addLayer(bio_2021.select(['agb_t_ha']).updateMask(k1), {
#           "min": 1, "max": 100, "palette": biomass_palette}, 'CCI AGB Density')
# m.addLayer(agb_2021.select(['AGB']), {
#     "min": 1, "max": 100, "palette": biomass_palette}, 'CCI AGB Density')
# m.addLayer(k1, {"min": 0, "max": 1}, 'K1 Mountain Classification')
# m.addLayer(wte.updateMask(lc.mask()), {"min": 1, "max": 450, "palette": biomass_palette}, "WTE")
# m.addLayer(irr_carbon_biomass, {"min": 1, "max": 450, "palette": biomass_palette}, "Irrecoverable Carbon Biomass 2018")
# m.addLayer(irr_carbon_soc, {"min": 1, "max": 450, "palette": biomass_palette}, "Irrecoverable Carbon SOC 2018")
# m.addLayer(irr_carbon.updateMask(k1), {"min": 1, "max": 450, "palette": biomass_palette}, "Irrecoverable Carbon K1 2018")
# m.addLayer(irr_carbon.updateMask(k1.Not()), {"min": 1, "max": 450, "palette": biomass_palette}, "Irrecoverable Carbon Not K1 2018")
# m.addLayer(countries, {}, 'Countries')
m.addLayer(us_can, {}, 'US and Canada')
m.addLayer(pixel_area_ha.clipToCollection(us_can).updateMask(k1.Not()), {}, "Pixel Area Ha in K1")

# Display the map
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…
