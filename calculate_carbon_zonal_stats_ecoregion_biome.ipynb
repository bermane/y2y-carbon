# %% [markdown]
# This code takes the reprojected carbon stock layers and calculates zonal statistics across the y2y region based on ecoregion and biome attributes.

# %%
# import packages
import geopandas as gpd
import numpy as np
import rioxarray as rxr
import xarray

import pandas as pd
from pandas.api.types import is_numeric_dtype

from geocube.api.core import make_geocube

import warnings

# %%
# load 2017 ecoregions clipped to y2y and reproject to match rasters
eco = gpd.read_file('./land_cover/ecoregions2017_clipped.shp').to_crs(
    '+proj=laea +lat_0=55 +lon_0=-125 +x_0=0 +y_0=0 +datum=WGS84 +units=m +no_defs')
eco
# Out:
#     OBJECTID                                       ECO_NAME  BIOME_NUM  \
# 0       13.0     Alberta-British Columbia foothills forests        5.0
# 1       74.0                         Blue Mountains forests        5.0
# 2       83.0       British Columbia coastal conifer forests        5.0
# 3       84.0                    Brooks-British Range tundra       11.0
# 4       95.0           Canadian Aspen forests and parklands        8.0
# 5      133.0      Central British Columbia Mountain forests        5.0
# 6      272.0       Fraser Plateau and Basin conifer forests        5.0
# 7      337.0            Interior Alaska-Yukon lowland taiga        6.0
# 8      339.0            Interior Yukon-Alaska alpine tundra       11.0
# 9      438.0               Mid-Canada Boreal Plains forests        6.0
# 10     451.0         Montana Valley and Foothill grasslands        8.0
# 11     457.0                        Muskwa-Slave Lake taiga        6.0
# 12     518.0                    Northern Shortgrass prairie        8.0
# 13     539.0                Ogilvie-MacKenzie alpine tundra       11.0
# 14     540.0                           Okanogan dry forests        5.0
# 15     548.0  Pacific Coastal Mountain icefields and tundra       11.0
# 16     551.0                                Palouse prairie        8.0
# 17     637.0                    Snake-Columbia shrub steppe       13.0
# 18     648.0                  South Central Rockies forests        5.0
# 19     777.0              Wasatch and Uinta montane forests        5.0
# 20     778.0                         Watson Highlands taiga        6.0
# 21     802.0                     Wyoming Basin shrub steppe       13.0
# 22     821.0                    Northern Cordillera forests        6.0
# 23     828.0                    Northwest Territories taiga        6.0
# 24     839.0               Northern Rockies conifer forests        5.0
#
#                                      BIOME_NAME     REALM ECO_BIOME_  NNH  \
# 0                     Temperate Conifer Forests  Nearctic       NE05    2
# 1                     Temperate Conifer Forests  Nearctic       NE05    3
# 2                     Temperate Conifer Forests  Nearctic       NE05    2
# 3                                        Tundra  Nearctic       NE11    1
# 4   Temperate Grasslands, Savannas & Shrublands  Nearctic       NE08    4
# 5                     Temperate Conifer Forests  Nearctic       NE05    2
# 6                     Temperate Conifer Forests  Nearctic       NE05    3
# 7                          Boreal Forests/Taiga  Nearctic       NE06    2
# 8                                        Tundra  Nearctic       NE11    2
# 9                          Boreal Forests/Taiga  Nearctic       NE06    2
# 10  Temperate Grasslands, Savannas & Shrublands  Nearctic       NE08    3
# 11                         Boreal Forests/Taiga  Nearctic       NE06    2
# 12  Temperate Grasslands, Savannas & Shrublands  Nearctic       NE08    3
# 13                                       Tundra  Nearctic       NE11    2
# 14                    Temperate Conifer Forests  Nearctic       NE05    3
# 15                                       Tundra  Nearctic       NE11    1
# 16  Temperate Grasslands, Savannas & Shrublands  Nearctic       NE08    3
# 17                   Deserts & Xeric Shrublands  Nearctic       NE13    2
# 18                    Temperate Conifer Forests  Nearctic       NE05    3
# 19                    Temperate Conifer Forests  Nearctic       NE05    3
# 20                         Boreal Forests/Taiga  Nearctic       NE06    2
# 21                   Deserts & Xeric Shrublands  Nearctic       NE13    2
# 22                         Boreal Forests/Taiga  Nearctic       NE06    2
# 23                         Boreal Forests/Taiga  Nearctic       NE06    2
# 24                    Temperate Conifer Forests  Nearctic       NE05    2
#
#     ECO_ID  SHAPE_LENG  SHAPE_AREA                           NNH_NAME  \
# 0      345   62.333821   17.133639  Nature Could Reach Half Protected
# 1      348   22.624165    8.066966               Nature Could Recover
# 2      349   86.917940   14.653986  Nature Could Reach Half Protected
# 3      411   87.112754   34.783625                     Half Protected
# 4      386   86.836978   40.677412                   Nature Imperiled
# 5      350   36.323846   19.868732  Nature Could Reach Half Protected
# 6      355   26.796172   13.925479               Nature Could Recover
# 7      375  199.626313   80.342543  Nature Could Reach Half Protected
# 8      416  121.006872   29.065154  Nature Could Reach Half Protected
# 9      376  109.724632   79.516771  Nature Could Reach Half Protected
# 10     394  140.881940   11.775151               Nature Could Recover
# 11     378   54.087197   47.946357  Nature Could Reach Half Protected
# 12     396  112.480037   86.168963               Nature Could Recover
# 13     419   68.627728   56.451765  Nature Could Reach Half Protected
# 14     362   15.925894    6.652011               Nature Could Recover
# 15     420  224.746133   16.851341                     Half Protected
# 16     398   38.384860    9.866972               Nature Could Recover
# 17     434   53.653702   21.216821  Nature Could Reach Half Protected
# 18     367  126.922931   20.091093               Nature Could Recover
# 19     368   29.642392    4.803558               Nature Could Recover
# 20     383   62.773339   40.325182  Nature Could Reach Half Protected
# 21     438   39.080210   14.520123  Nature Could Reach Half Protected
# 22     380   44.871996   26.034401  Nature Could Reach Half Protected
# 23     381   72.283572   64.674744  Nature Could Reach Half Protected
# 24     361   56.924527   35.905513  Nature Could Reach Half Protected
#
#       COLOR COLOR_BIO COLOR_NNH    LICENSE  \
# 0   #5DAD4C   #458970   #7BC141  CC-BY 4.0
# 1   #35A85A   #458970   #F9A91B  CC-BY 4.0
# 2   #00A884   #458970   #7BC141  CC-BY 4.0
# 3   #66BECA   #9ED7C2   #257339  CC-BY 4.0
# 4   #DB931A   #FEFF73   #EE1E23  CC-BY 4.0
# 5   #4CD970   #458970   #7BC141  CC-BY 4.0
# 6   #5ABD7A   #458970   #F9A91B  CC-BY 4.0
# 7   #6D3EC2   #7AB6F5   #7BC141  CC-BY 4.0
# 8   #6EE3C6   #9ED7C2   #7BC141  CC-BY 4.0
# 9   #DCB1F9   #7AB6F5   #7BC141  CC-BY 4.0
# 10  #C66E02   #FEFF73   #F9A91B  CC-BY 4.0
# 11  #9A72F7   #7AB6F5   #7BC141  CC-BY 4.0
# 12  #FCBA26   #FEFF73   #F9A91B  CC-BY 4.0
# 13  #74D0E7   #9ED7C2   #7BC141  CC-BY 4.0
# 14  #6BE381   #458970   #F9A91B  CC-BY 4.0
# 15  #4C82B6   #9ED7C2   #257339  CC-BY 4.0
# 16  #FDA65F   #FEFF73   #F9A91B  CC-BY 4.0
# 17  #C4694E   #CC6767   #7BC141  CC-BY 4.0
# 18  #058047   #458970   #F9A91B  CC-BY 4.0
# 19  #38A700   #458970   #F9A91B  CC-BY 4.0
# 20  #CDB0E0   #7AB6F5   #7BC141  CC-BY 4.0
# 21  #B57C47   #CC6767   #7BC141  CC-BY 4.0
# 22  #882AC8   #7AB6F5   #7BC141  CC-BY 4.0
# 23  #7E46E9   #7AB6F5   #7BC141  CC-BY 4.0
# 24  #ACC13E   #458970   #7BC141  CC-BY 4.0
#
#                                              geometry
# 0   MULTIPOLYGON (((231107.227 305009.454, 226734....
# 1   POLYGON ((614252.395 -1139094.041, 612099.656 ...
# 2   POLYGON ((-166421.245 37682.88, -177859.583 32...
# 3   MULTIPOLYGON (((-514179.871 1392834.151, -5147...
# 4   MULTIPOLYGON (((725180.479 -339910.34, 723716....
# 5   POLYGON ((192654.361 -120678.524, 194329.256 -...
# 6   POLYGON ((298504.267 -341027.666, 298711.41 -3...
# 7   MULTIPOLYGON (((-627905.705 1421020.585, -6225...
# 8   MULTIPOLYGON (((-713662.418 1111909.509, -7138...
# 9   MULTIPOLYGON (((253378.224 142341.081, 266856....
# 10  MULTIPOLYGON (((761734.834 -441379.54, 761096....
# 11  POLYGON ((95410.16 872210.206, 96382.604 84749...
# 12  MULTIPOLYGON (((810422.856 -485519.04, 821381....
# 13  MULTIPOLYGON (((-755976.703 1182178.805, -7559...
# 14  MULTIPOLYGON (((474577.166 -625673.034, 473110...
# 15  POLYGON ((-272462.322 138751.041, -273936.73 1...
# 16  MULTIPOLYGON (((515405.854 -995960.586, 528108...
# 17  MULTIPOLYGON (((1110000.92 -1277347.136, 11039...
# 18  MULTIPOLYGON (((1183080.637 -911918.231, 11830...
# 19  POLYGON ((1121134.459 -1287486.12, 1116521.321...
# 20  POLYGON ((-411929.754 569605.288, -411817.914 ...
# 21  POLYGON ((1244350.618 -964176.711, 1247304.004...
# 22  POLYGON ((-356700.609 261256.416, -358733.035 ...
# 23  MULTIPOLYGON (((-398203.134 1369022.794, -3811...
# 24  POLYGON ((602690.988 -820279.059, 602996.387 -...

# %%
# filter by columns needed
eco = eco.filter(
    ['OBJECTID', 'ECO_NAME', 'BIOME_NUM', 'BIOME_NAME', 'geometry'])
eco
# Out:
#     OBJECTID                                       ECO_NAME  BIOME_NUM  \
# 0       13.0     Alberta-British Columbia foothills forests        5.0
# 1       74.0                         Blue Mountains forests        5.0
# 2       83.0       British Columbia coastal conifer forests        5.0
# 3       84.0                    Brooks-British Range tundra       11.0
# 4       95.0           Canadian Aspen forests and parklands        8.0
# 5      133.0      Central British Columbia Mountain forests        5.0
# 6      272.0       Fraser Plateau and Basin conifer forests        5.0
# 7      337.0            Interior Alaska-Yukon lowland taiga        6.0
# 8      339.0            Interior Yukon-Alaska alpine tundra       11.0
# 9      438.0               Mid-Canada Boreal Plains forests        6.0
# 10     451.0         Montana Valley and Foothill grasslands        8.0
# 11     457.0                        Muskwa-Slave Lake taiga        6.0
# 12     518.0                    Northern Shortgrass prairie        8.0
# 13     539.0                Ogilvie-MacKenzie alpine tundra       11.0
# 14     540.0                           Okanogan dry forests        5.0
# 15     548.0  Pacific Coastal Mountain icefields and tundra       11.0
# 16     551.0                                Palouse prairie        8.0
# 17     637.0                    Snake-Columbia shrub steppe       13.0
# 18     648.0                  South Central Rockies forests        5.0
# 19     777.0              Wasatch and Uinta montane forests        5.0
# 20     778.0                         Watson Highlands taiga        6.0
# 21     802.0                     Wyoming Basin shrub steppe       13.0
# 22     821.0                    Northern Cordillera forests        6.0
# 23     828.0                    Northwest Territories taiga        6.0
# 24     839.0               Northern Rockies conifer forests        5.0
#
#                                      BIOME_NAME  \
# 0                     Temperate Conifer Forests
# 1                     Temperate Conifer Forests
# 2                     Temperate Conifer Forests
# 3                                        Tundra
# 4   Temperate Grasslands, Savannas & Shrublands
# 5                     Temperate Conifer Forests
# 6                     Temperate Conifer Forests
# 7                          Boreal Forests/Taiga
# 8                                        Tundra
# 9                          Boreal Forests/Taiga
# 10  Temperate Grasslands, Savannas & Shrublands
# 11                         Boreal Forests/Taiga
# 12  Temperate Grasslands, Savannas & Shrublands
# 13                                       Tundra
# 14                    Temperate Conifer Forests
# 15                                       Tundra
# 16  Temperate Grasslands, Savannas & Shrublands
# 17                   Deserts & Xeric Shrublands
# 18                    Temperate Conifer Forests
# 19                    Temperate Conifer Forests
# 20                         Boreal Forests/Taiga
# 21                   Deserts & Xeric Shrublands
# 22                         Boreal Forests/Taiga
# 23                         Boreal Forests/Taiga
# 24                    Temperate Conifer Forests
#
#                                              geometry
# 0   MULTIPOLYGON (((231107.227 305009.454, 226734....
# 1   POLYGON ((614252.395 -1139094.041, 612099.656 ...
# 2   POLYGON ((-166421.245 37682.88, -177859.583 32...
# 3   MULTIPOLYGON (((-514179.871 1392834.151, -5147...
# 4   MULTIPOLYGON (((725180.479 -339910.34, 723716....
# 5   POLYGON ((192654.361 -120678.524, 194329.256 -...
# 6   POLYGON ((298504.267 -341027.666, 298711.41 -3...
# 7   MULTIPOLYGON (((-627905.705 1421020.585, -6225...
# 8   MULTIPOLYGON (((-713662.418 1111909.509, -7138...
# 9   MULTIPOLYGON (((253378.224 142341.081, 266856....
# 10  MULTIPOLYGON (((761734.834 -441379.54, 761096....
# 11  POLYGON ((95410.16 872210.206, 96382.604 84749...
# 12  MULTIPOLYGON (((810422.856 -485519.04, 821381....
# 13  MULTIPOLYGON (((-755976.703 1182178.805, -7559...
# 14  MULTIPOLYGON (((474577.166 -625673.034, 473110...
# 15  POLYGON ((-272462.322 138751.041, -273936.73 1...
# 16  MULTIPOLYGON (((515405.854 -995960.586, 528108...
# 17  MULTIPOLYGON (((1110000.92 -1277347.136, 11039...
# 18  MULTIPOLYGON (((1183080.637 -911918.231, 11830...
# 19  POLYGON ((1121134.459 -1287486.12, 1116521.321...
# 20  POLYGON ((-411929.754 569605.288, -411817.914 ...
# 21  POLYGON ((1244350.618 -964176.711, 1247304.004...
# 22  POLYGON ((-356700.609 261256.416, -358733.035 ...
# 23  MULTIPOLYGON (((-398203.134 1369022.794, -3811...
# 24  POLYGON ((602690.988 -820279.059, 602996.387 -...

# %%
# rename id columns
eco = eco.rename(columns={'OBJECTID': 'ECO_ID', 'BIOME_NUM': 'BIOME_ID'})
eco
# Out:
#     ECO_ID                                       ECO_NAME  BIOME_ID  \
# 0     13.0     Alberta-British Columbia foothills forests       5.0
# 1     74.0                         Blue Mountains forests       5.0
# 2     83.0       British Columbia coastal conifer forests       5.0
# 3     84.0                    Brooks-British Range tundra      11.0
# 4     95.0           Canadian Aspen forests and parklands       8.0
# 5    133.0      Central British Columbia Mountain forests       5.0
# 6    272.0       Fraser Plateau and Basin conifer forests       5.0
# 7    337.0            Interior Alaska-Yukon lowland taiga       6.0
# 8    339.0            Interior Yukon-Alaska alpine tundra      11.0
# 9    438.0               Mid-Canada Boreal Plains forests       6.0
# 10   451.0         Montana Valley and Foothill grasslands       8.0
# 11   457.0                        Muskwa-Slave Lake taiga       6.0
# 12   518.0                    Northern Shortgrass prairie       8.0
# 13   539.0                Ogilvie-MacKenzie alpine tundra      11.0
# 14   540.0                           Okanogan dry forests       5.0
# 15   548.0  Pacific Coastal Mountain icefields and tundra      11.0
# 16   551.0                                Palouse prairie       8.0
# 17   637.0                    Snake-Columbia shrub steppe      13.0
# 18   648.0                  South Central Rockies forests       5.0
# 19   777.0              Wasatch and Uinta montane forests       5.0
# 20   778.0                         Watson Highlands taiga       6.0
# 21   802.0                     Wyoming Basin shrub steppe      13.0
# 22   821.0                    Northern Cordillera forests       6.0
# 23   828.0                    Northwest Territories taiga       6.0
# 24   839.0               Northern Rockies conifer forests       5.0
#
#                                      BIOME_NAME  \
# 0                     Temperate Conifer Forests
# 1                     Temperate Conifer Forests
# 2                     Temperate Conifer Forests
# 3                                        Tundra
# 4   Temperate Grasslands, Savannas & Shrublands
# 5                     Temperate Conifer Forests
# 6                     Temperate Conifer Forests
# 7                          Boreal Forests/Taiga
# 8                                        Tundra
# 9                          Boreal Forests/Taiga
# 10  Temperate Grasslands, Savannas & Shrublands
# 11                         Boreal Forests/Taiga
# 12  Temperate Grasslands, Savannas & Shrublands
# 13                                       Tundra
# 14                    Temperate Conifer Forests
# 15                                       Tundra
# 16  Temperate Grasslands, Savannas & Shrublands
# 17                   Deserts & Xeric Shrublands
# 18                    Temperate Conifer Forests
# 19                    Temperate Conifer Forests
# 20                         Boreal Forests/Taiga
# 21                   Deserts & Xeric Shrublands
# 22                         Boreal Forests/Taiga
# 23                         Boreal Forests/Taiga
# 24                    Temperate Conifer Forests
#
#                                              geometry
# 0   MULTIPOLYGON (((231107.227 305009.454, 226734....
# 1   POLYGON ((614252.395 -1139094.041, 612099.656 ...
# 2   POLYGON ((-166421.245 37682.88, -177859.583 32...
# 3   MULTIPOLYGON (((-514179.871 1392834.151, -5147...
# 4   MULTIPOLYGON (((725180.479 -339910.34, 723716....
# 5   POLYGON ((192654.361 -120678.524, 194329.256 -...
# 6   POLYGON ((298504.267 -341027.666, 298711.41 -3...
# 7   MULTIPOLYGON (((-627905.705 1421020.585, -6225...
# 8   MULTIPOLYGON (((-713662.418 1111909.509, -7138...
# 9   MULTIPOLYGON (((253378.224 142341.081, 266856....
# 10  MULTIPOLYGON (((761734.834 -441379.54, 761096....
# 11  POLYGON ((95410.16 872210.206, 96382.604 84749...
# 12  MULTIPOLYGON (((810422.856 -485519.04, 821381....
# 13  MULTIPOLYGON (((-755976.703 1182178.805, -7559...
# 14  MULTIPOLYGON (((474577.166 -625673.034, 473110...
# 15  POLYGON ((-272462.322 138751.041, -273936.73 1...
# 16  MULTIPOLYGON (((515405.854 -995960.586, 528108...
# 17  MULTIPOLYGON (((1110000.92 -1277347.136, 11039...
# 18  MULTIPOLYGON (((1183080.637 -911918.231, 11830...
# 19  POLYGON ((1121134.459 -1287486.12, 1116521.321...
# 20  POLYGON ((-411929.754 569605.288, -411817.914 ...
# 21  POLYGON ((1244350.618 -964176.711, 1247304.004...
# 22  POLYGON ((-356700.609 261256.416, -358733.035 ...
# 23  MULTIPOLYGON (((-398203.134 1369022.794, -3811...
# 24  POLYGON ((602690.988 -820279.059, 602996.387 -...

# %%
# define function to extract zonal stats
def extract_stats(dat_fp, dat_name, vector, vect_var, stat):

    # Suppress UserWarning within this function
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning)

        # create new vect variable so don't edit data in place
        vect = vector.copy()

        # check if vect_var column is numeric
        numeric = True
        if not is_numeric_dtype(vect[vect_var]):
            vect['key'] = pd.factorize(vect[vect_var])[0]
            vect.rename(columns={vect_var: 'orig_name',
                        'key': vect_var}, inplace=True)
            numeric = False

        # clip data to vector layer
        dat = rxr.open_rasterio(dat_fp, masked=True
                                ).rio.clip(vect.geometry.values, vect.crs, from_disk=True)
        dat.name = dat_name

        # create output grid
        out_grid = make_geocube(
            vector_data=vect,
            measurements=[vect_var],
            like=dat
        )

        # merge the datacube with the data
        out_grid[dat_name] = (dat.dims, dat.values,
                              dat.attrs, dat.encoding)

        # group data by vector variable
        grouped = out_grid.drop_vars(['spatial_ref']).groupby(vect_var)

        # calculate stats
        if stat == 'sum':
            table = grouped.sum()
        if stat == 'mean':
            table = grouped.mean()

        # reset indicies and drop band
        table = table.to_dataframe()
        table.reset_index(level='band', drop=True, inplace=True)

        # reset keys to original values
        if numeric == False:
            mapping = dict(zip(vect[vect_var], vect['orig_name']))
            table.index = table.index.map(mapping)

        # return table
        return table

# %%
# load carbon rasters in format for zonal stats function
# file paths
carbon_fp = ['./carbon_stock_data/output_layers/carbon_sothe_spawn_t_laea.tif',
             './carbon_stock_data/output_layers/soc_0_1m_t_laea.tif',
             './carbon_flux_data/output_layers/emissions_gfw_t_yr_laea.tif',
             './carbon_flux_data/output_layers/removals_gfw_t_yr_laea.tif',
             './carbon_stock_data/output_layers/carbon_sothe_spawn_t_ha_laea.tif',
             './carbon_stock_data/output_layers/soc_0_1m_t_ha_laea.tif',
             './carbon_flux_data/output_layers/emissions_gfw_t_ha_laea.tif',
             './carbon_flux_data/output_layers/removals_gfw_t_ha_laea.tif']

carbon_names = ['carbon_t',
                'soc_t',
                'emissions_t_yr',
                'removals_t_yr',
                'carbon_t_ha',
                'soc_t_ha',
                'emissions_t_ha',
                'removals_t_ha']

stat_names = ['sum',
              'sum',
              'sum',
              'sum',
              'mean',
              'mean',
              'mean',
              'mean']

# %%
# extract zonal stats by ecoregion
for i in range(len(carbon_fp)):
    if i == 0:
        stats_eco = extract_stats(
            dat_fp=carbon_fp[i], dat_name=carbon_names[i], vector=eco, vect_var='ECO_NAME', stat=stat_names[i])
    else:
        stats_eco = pd.concat([stats_eco,
                               extract_stats(dat_fp=carbon_fp[i], dat_name=carbon_names[i], vector=eco, vect_var='ECO_NAME', stat=stat_names[i])],
                              axis=1)

# %%
# extract zonal stats by biome
for i in range(len(carbon_fp)):
    if i == 0:
        stats_biome = extract_stats(
            dat_fp=carbon_fp[i], dat_name=carbon_names[i], vector=eco, vect_var='BIOME_NAME', stat=stat_names[i])
    else:
        stats_biome = pd.concat([stats_biome,
                                 extract_stats(dat_fp=carbon_fp[i], dat_name=carbon_names[i], vector=eco, vect_var='BIOME_NAME', stat=stat_names[i])],
                                axis=1)

# %%
# total carbon stored (+sanity check should be equal across tables)
print(stats_eco['carbon_t'].sum())
print(stats_biome['carbon_t'].sum())
print(stats_eco['soc_t'].sum())
print(stats_biome['soc_t'].sum())
# Out:
# 5550111329.265042
# 5550111329.265044
# 28361623946.672928
# 28361623946.672928

# %%
# add total area to eco
eco['area'] = eco.geometry.area

# create new row to add to stats_eco
new_row = pd.DataFrame(
    {'ECO_NAME': eco['ECO_NAME'], 'area_km2': eco['area'] / 1e+6})
new_row.set_index('ECO_NAME', inplace=True)

# concat to stats
stats_eco = pd.concat([stats_eco, new_row], axis=1)
stats_eco
# Out:
#                                                    carbon_t         soc_t  \
# ECO_NAME
# Alberta-British Columbia foothills forests     2.356169e+08  6.285775e+08
# Blue Mountains forests                         1.413623e+08  3.259319e+08
# British Columbia coastal conifer forests       4.251368e+07  9.087393e+07
# Brooks-British Range tundra                    7.826235e+06  1.353119e+08
# Canadian Aspen forests and parklands           2.829307e+06  3.232623e+07
# Central British Columbia Mountain forests      6.074951e+08  1.697009e+09
# Fraser Plateau and Basin conifer forests       4.557070e+04  1.297867e+05
# Interior Alaska-Yukon lowland taiga            1.092599e+06  5.882381e+07
# Interior Yukon-Alaska alpine tundra            4.798406e+06  2.643832e+07
# Mid-Canada Boreal Plains forests               4.812699e+07  1.070786e+08
# Montana Valley and Foothill grasslands         9.322048e+07  7.314547e+08
# Muskwa-Slave Lake taiga                        2.862036e+08  1.399765e+09
# Northern Shortgrass prairie                    2.308452e+06  4.401323e+07
# Ogilvie-MacKenzie alpine tundra                4.606841e+08  7.287563e+09
# Okanogan dry forests                           3.784333e+07  1.430960e+08
# Pacific Coastal Mountain icefields and tundra  5.363582e+05  2.216578e+06
# Palouse prairie                                7.832974e+06  6.164358e+07
# Snake-Columbia shrub steppe                    8.205512e+06  9.672624e+07
# South Central Rockies forests                  7.443096e+08  2.115499e+09
# Wasatch and Uinta montane forests              7.905040e+04  1.014424e+06
# Watson Highlands taiga                         6.460944e+08  3.343963e+09
# Wyoming Basin shrub steppe                     1.216978e+07  1.825590e+08
# Northern Cordillera forests                    4.658027e+08  2.492307e+09
# Northwest Territories taiga                    4.704424e+07  1.033860e+09
# Northern Rockies conifer forests               1.646070e+09  6.323441e+09
#
#                                                emissions_t_yr  removals_t_yr  \
# ECO_NAME
# Alberta-British Columbia foothills forests       3.220553e+06   2.661132e+06
# Blue Mountains forests                           7.678736e+05   8.469301e+05
# British Columbia coastal conifer forests         5.129060e+04   4.845318e+05
# Brooks-British Range tundra                      2.644100e+03   1.670310e+04
# Canadian Aspen forests and parklands             2.298000e+02   3.033440e+04
# Central British Columbia Mountain forests        3.203280e+06   9.401294e+06
# Fraser Plateau and Basin conifer forests         6.697000e+02   8.264000e+02
# Interior Alaska-Yukon lowland taiga              1.651130e+04   1.678170e+04
# Interior Yukon-Alaska alpine tundra              1.311100e+03   7.181260e+04
# Mid-Canada Boreal Plains forests                 2.924003e+05   4.805934e+05
# Montana Valley and Foothill grasslands           1.943844e+05   4.839107e+05
# Muskwa-Slave Lake taiga                          1.743859e+06   1.126755e+06
# Northern Shortgrass prairie                      0.000000e+00   2.677600e+03
# Ogilvie-MacKenzie alpine tundra                  4.376774e+06   4.801914e+06
# Okanogan dry forests                             4.845751e+05   1.216765e+05
# Pacific Coastal Mountain icefields and tundra    0.000000e+00   8.912400e+03
# Palouse prairie                                  4.303780e+04   4.363760e+04
# Snake-Columbia shrub steppe                      6.990900e+03   1.763460e+04
# South Central Rockies forests                    4.301030e+06   4.920338e+06
# Wasatch and Uinta montane forests                0.000000e+00   2.880000e+01
# Watson Highlands taiga                           3.447996e+06   9.960994e+06
# Wyoming Basin shrub steppe                       1.092630e+04   1.098660e+04
# Northern Cordillera forests                      9.227190e+05   6.127985e+06
# Northwest Territories taiga                      8.011326e+05   2.574870e+05
# Northern Rockies conifer forests                 9.701691e+06   2.068142e+07
#
#                                                carbon_t_ha    soc_t_ha  \
# ECO_NAME
# Alberta-British Columbia foothills forests       51.875723  138.438498
# Blue Mountains forests                           51.002047  117.833526
# British Columbia coastal conifer forests         95.729952  205.112782
# Brooks-British Range tundra                      17.801833  307.750048
# Canadian Aspen forests and parklands             21.429108  244.942044
# Central British Columbia Mountain forests        62.469650  174.624412
# Fraser Plateau and Basin conifer forests         59.765574  170.211475
# Interior Alaska-Yukon lowland taiga              17.724394  961.860991
# Interior Yukon-Alaska alpine tundra              45.780841  253.180004
# Mid-Canada Boreal Plains forests                 49.877737  111.053668
# Montana Valley and Foothill grasslands           14.352652  112.950052
# Muskwa-Slave Lake taiga                          58.659251  287.203817
# Northern Shortgrass prairie                       6.372858  121.682259
# Ogilvie-MacKenzie alpine tundra                  16.801329  265.895646
# Okanogan dry forests                             58.028580  219.718776
# Pacific Coastal Mountain icefields and tundra    62.051193  259.438332
# Palouse prairie                                  15.151702  120.478506
# Snake-Columbia shrub steppe                       9.112353  108.220603
# South Central Rockies forests                    49.316417  140.338805
# Wasatch and Uinta montane forests                10.673755  136.968777
# Watson Highlands taiga                           39.390640  204.187256
# Wyoming Basin shrub steppe                        6.112755   91.887956
# Northern Cordillera forests                      35.865359  192.026795
# Northwest Territories taiga                      31.138267  686.229446
# Northern Rockies conifer forests                 64.521164  248.462573
#
#                                                emissions_t_ha  removals_t_ha  \
# ECO_NAME
# Alberta-British Columbia foothills forests          85.490704      14.127711
# Blue Mountains forests                             101.260543      15.360629
# British Columbia coastal conifer forests           100.342637      28.506463
# Brooks-British Range tundra                         15.862153       5.442696
# Canadian Aspen forests and parklands                84.560000      20.324964
# Central British Columbia Mountain forests           92.102152      27.132965
# Fraser Plateau and Basin conifer forests            88.039285      24.739837
# Interior Alaska-Yukon lowland taiga                164.232433      17.038969
# Interior Yukon-Alaska alpine tundra                 26.659668      17.825111
# Mid-Canada Boreal Plains forests                    77.718620      13.938594
# Montana Valley and Foothill grasslands             100.937534      15.885756
# Muskwa-Slave Lake taiga                             63.055603       5.559164
# Northern Shortgrass prairie                               NaN      22.836659
# Ogilvie-MacKenzie alpine tundra                    102.611594      12.185699
# Okanogan dry forests                                92.262836       4.790733
# Pacific Coastal Mountain icefields and tundra             NaN      28.945631
# Palouse prairie                                    121.365364      21.191213
# Snake-Columbia shrub steppe                         88.407216      16.450165
# South Central Rockies forests                       65.983166      12.856737
# Wasatch and Uinta montane forests                         NaN      11.766667
# Watson Highlands taiga                              59.168451      16.721361
# Wyoming Basin shrub steppe                          87.224295       9.299332
# Northern Cordillera forests                         53.871246      17.419692
# Northwest Territories taiga                        140.449235       6.127260
# Northern Rockies conifer forests                    89.502747      25.214080
#
#                                                     area_km2
# ECO_NAME
# Alberta-British Columbia foothills forests      45822.772034
# Blue Mountains forests                          27834.980830
# British Columbia coastal conifer forests         4602.328781
# Brooks-British Range tundra                      4441.500901
# Canadian Aspen forests and parklands             1327.364826
# Central British Columbia Mountain forests      100935.318708
# Fraser Plateau and Basin conifer forests            8.007105
# Interior Alaska-Yukon lowland taiga               709.394041
# Interior Yukon-Alaska alpine tundra              1108.112140
# Mid-Canada Boreal Plains forests                 9866.388366
# Montana Valley and Foothill grasslands          65395.844191
# Muskwa-Slave Lake taiga                         50558.509526
# Northern Shortgrass prairie                      3662.876604
# Ogilvie-MacKenzie alpine tundra                278156.097469
# Okanogan dry forests                             6759.698682
# Pacific Coastal Mountain icefields and tundra     101.094907
# Palouse prairie                                  5192.537612
# Snake-Columbia shrub steppe                      9098.659914
# South Central Rockies forests                  152182.916658
# Wasatch and Uinta montane forests                  74.772602
# Watson Highlands taiga                         167523.328045
# Wyoming Basin shrub steppe                      20030.521854
# Northern Cordillera forests                    132245.724711
# Northwest Territories taiga                     16221.410859
# Northern Rockies conifer forests               266022.107828

# %%
# add area to biomes
new_row = pd.DataFrame({'BIOME_NAME': eco.groupby('BIOME_NAME')['area'].sum().index.values,
                        'area_km2': eco.groupby('BIOME_NAME')['area'].sum().values / 1e+6})
new_row.set_index('BIOME_NAME', inplace=True)

# concat to stats
stats_biome = pd.concat([stats_biome, new_row], axis=1)
stats_biome
# Out:
#                                                  carbon_t         soc_t  \
# BIOME_NAME
# Temperate Conifer Forests                    3.455335e+09  1.132557e+10
# Tundra                                       4.738451e+08  7.451530e+09
# Temperate Grasslands, Savannas & Shrublands  1.061912e+08  8.694378e+08
# Boreal Forests/Taiga                         1.494365e+09  8.435799e+09
# Deserts & Xeric Shrublands                   2.037529e+07  2.792852e+08
#
#                                              emissions_t_yr  removals_t_yr  \
# BIOME_NAME
# Temperate Conifer Forests                      2.173096e+07   3.911818e+07
# Tundra                                         4.380729e+06   4.899342e+06
# Temperate Grasslands, Savannas & Shrublands    2.376520e+05   5.605603e+05
# Boreal Forests/Taiga                           7.224619e+06   1.797060e+07
# Deserts & Xeric Shrublands                     1.791720e+04   2.862120e+04
#
#                                              carbon_t_ha    soc_t_ha  \
# BIOME_NAME
# Temperate Conifer Forests                      58.816887  193.099275
# Tundra                                         16.939621  266.504353
# Temperate Grasslands, Savannas & Shrublands    14.147048  116.215565
# Boreal Forests/Taiga                           40.600871  229.473025
# Deserts & Xeric Shrublands                      7.046919   96.955720
#
#                                              emissions_t_ha  removals_t_ha  \
# BIOME_NAME
# Temperate Conifer Forests                         83.779040      21.312636
# Tundra                                           102.187378      12.203409
# Temperate Grasslands, Savannas & Shrublands      104.090895      16.423994
# Boreal Forests/Taiga                              64.147422      14.638687
# Deserts & Xeric Shrublands                        87.682048      12.702642
#
#                                                   area_km2
# BIOME_NAME
# Temperate Conifer Forests                    604242.903229
# Tundra                                       283806.805417
# Temperate Grasslands, Savannas & Shrublands   75578.623233
# Boreal Forests/Taiga                         377124.755549
# Deserts & Xeric Shrublands                    29129.181768

# %%
# export to csv
stats_eco.to_excel(
    './outputs/y2y_carbon_ecoregions.xlsx', index=True)

stats_biome.to_excel(
    './outputs/y2y_carbon_biomes.xlsx', index=True)

# %%
# add ecoregion stats to vector data
ecoregions = eco.merge(stats_eco, on='ECO_ID')
ecoregions
# Out:
#     ECO_ID                                       ECO_NAME  BIOME_ID  \
# 0     13.0     Alberta-British Columbia foothills forests       5.0
# 1     74.0                         Blue Mountains forests       5.0
# 2     83.0       British Columbia coastal conifer forests       5.0
# 3     84.0                    Brooks-British Range tundra      11.0
# 4     95.0           Canadian Aspen forests and parklands       8.0
# 5    133.0      Central British Columbia Mountain forests       5.0
# 6    272.0       Fraser Plateau and Basin conifer forests       5.0
# 7    337.0            Interior Alaska-Yukon lowland taiga       6.0
# 8    339.0            Interior Yukon-Alaska alpine tundra      11.0
# 9    438.0               Mid-Canada Boreal Plains forests       6.0
# 10   451.0         Montana Valley and Foothill grasslands       8.0
# 11   457.0                        Muskwa-Slave Lake taiga       6.0
# 12   518.0                    Northern Shortgrass prairie       8.0
# 13   539.0                Ogilvie-MacKenzie alpine tundra      11.0
# 14   540.0                           Okanogan dry forests       5.0
# 15   548.0  Pacific Coastal Mountain icefields and tundra      11.0
# 16   551.0                                Palouse prairie       8.0
# 17   637.0                    Snake-Columbia shrub steppe      13.0
# 18   648.0                  South Central Rockies forests       5.0
# 19   777.0              Wasatch and Uinta montane forests       5.0
# 20   778.0                         Watson Highlands taiga       6.0
# 21   802.0                     Wyoming Basin shrub steppe      13.0
# 22   821.0                    Northern Cordillera forests       6.0
# 23   828.0                    Northwest Territories taiga       6.0
# 24   839.0               Northern Rockies conifer forests       5.0
#
#                                      BIOME_NAME  \
# 0                     Temperate Conifer Forests
# 1                     Temperate Conifer Forests
# 2                     Temperate Conifer Forests
# 3                                        Tundra
# 4   Temperate Grasslands, Savannas & Shrublands
# 5                     Temperate Conifer Forests
# 6                     Temperate Conifer Forests
# 7                          Boreal Forests/Taiga
# 8                                        Tundra
# 9                          Boreal Forests/Taiga
# 10  Temperate Grasslands, Savannas & Shrublands
# 11                         Boreal Forests/Taiga
# 12  Temperate Grasslands, Savannas & Shrublands
# 13                                       Tundra
# 14                    Temperate Conifer Forests
# 15                                       Tundra
# 16  Temperate Grasslands, Savannas & Shrublands
# 17                   Deserts & Xeric Shrublands
# 18                    Temperate Conifer Forests
# 19                    Temperate Conifer Forests
# 20                         Boreal Forests/Taiga
# 21                   Deserts & Xeric Shrublands
# 22                         Boreal Forests/Taiga
# 23                         Boreal Forests/Taiga
# 24                    Temperate Conifer Forests
#
#                                              geometry  band  total_carbon  \
# 0   MULTIPOLYGON (((231107.227 305009.454, 226734....     0      0.235617
# 1   POLYGON ((614252.395 -1139094.041, 612099.656 ...     0      0.141362
# 2   POLYGON ((-166421.245 37682.88, -177859.583 32...     0      0.042514
# 3   MULTIPOLYGON (((-514179.871 1392834.151, -5147...     0      0.007826
# 4   MULTIPOLYGON (((725180.479 -339910.34, 723716....     0      0.002829
# 5   POLYGON ((192654.361 -120678.524, 194329.256 -...     0      0.607495
# 6   POLYGON ((298504.267 -341027.666, 298711.41 -3...     0      0.000046
# 7   MULTIPOLYGON (((-627905.705 1421020.585, -6225...     0      0.001093
# 8   MULTIPOLYGON (((-713662.418 1111909.509, -7138...     0      0.004798
# 9   MULTIPOLYGON (((253378.224 142341.081, 266856....     0      0.048127
# 10  MULTIPOLYGON (((761734.834 -441379.54, 761096....     0      0.093220
# 11  POLYGON ((95410.16 872210.206, 96382.604 84749...     0      0.286204
# 12  MULTIPOLYGON (((810422.856 -485519.04, 821381....     0      0.002308
# 13  MULTIPOLYGON (((-755976.703 1182178.805, -7559...     0      0.460684
# 14  MULTIPOLYGON (((474577.166 -625673.034, 473110...     0      0.037843
# 15  POLYGON ((-272462.322 138751.041, -273936.73 1...     0      0.000536
# 16  MULTIPOLYGON (((515405.854 -995960.586, 528108...     0      0.007833
# 17  MULTIPOLYGON (((1110000.92 -1277347.136, 11039...     0      0.008206
# 18  MULTIPOLYGON (((1183080.637 -911918.231, 11830...     0      0.744310
# 19  POLYGON ((1121134.459 -1287486.12, 1116521.321...     0      0.000079
# 20  POLYGON ((-411929.754 569605.288, -411817.914 ...     0      0.646094
# 21  POLYGON ((1244350.618 -964176.711, 1247304.004...     0      0.012170
# 22  POLYGON ((-356700.609 261256.416, -358733.035 ...     0      0.465803
# 23  MULTIPOLYGON (((-398203.134 1369022.794, -3811...     0      0.047044
# 24  POLYGON ((602690.988 -820279.059, 602996.387 -...     0      1.646070
#
#     total_soc  avg_carbon_density  avg_soc_density
# 0    0.628577           51.875723       138.438498
# 1    0.325932           51.002047       117.833526
# 2    0.090874           95.729952       205.112782
# 3    0.135312           17.801833       307.750048
# 4    0.032326           21.429108       244.942044
# 5    1.697009           62.469650       174.624412
# 6    0.000130           59.765574       170.211475
# 7    0.058824           17.724394       961.860991
# 8    0.026438           45.780841       253.180004
# 9    0.107079           49.877737       111.053668
# 10   0.731455           14.352652       112.950052
# 11   1.399765           58.659251       287.203817
# 12   0.044013            6.372858       121.682259
# 13   7.287563           16.801329       265.895646
# 14   0.143096           58.028580       219.718776
# 15   0.002217           62.051193       259.438332
# 16   0.061644           15.151702       120.478506
# 17   0.096726            9.112353       108.220603
# 18   2.115499           49.316417       140.338805
# 19   0.001014           10.673755       136.968777
# 20   3.343963           39.390640       204.187256
# 21   0.182559            6.112755        91.887956
# 22   2.492307           35.865359       192.026795
# 23   1.033860           31.138267       686.229446
# 24   6.323441           64.521164       248.462573

# %%
# clean up vector data
ecoregions.drop('band', axis=1, inplace=True)
ecoregions.rename(columns={'total_carbon': 'c_pg',
                           'total_soc': 'soc_pg',
                           'avg_carbon_density': 'c_t_ha',
                           'avg_soc_density': 'soc_t_ha'},
                  inplace=True)
ecoregions
# Out:
#     ECO_ID                                       ECO_NAME  BIOME_ID  \
# 0     13.0     Alberta-British Columbia foothills forests       5.0
# 1     74.0                         Blue Mountains forests       5.0
# 2     83.0       British Columbia coastal conifer forests       5.0
# 3     84.0                    Brooks-British Range tundra      11.0
# 4     95.0           Canadian Aspen forests and parklands       8.0
# 5    133.0      Central British Columbia Mountain forests       5.0
# 6    272.0       Fraser Plateau and Basin conifer forests       5.0
# 7    337.0            Interior Alaska-Yukon lowland taiga       6.0
# 8    339.0            Interior Yukon-Alaska alpine tundra      11.0
# 9    438.0               Mid-Canada Boreal Plains forests       6.0
# 10   451.0         Montana Valley and Foothill grasslands       8.0
# 11   457.0                        Muskwa-Slave Lake taiga       6.0
# 12   518.0                    Northern Shortgrass prairie       8.0
# 13   539.0                Ogilvie-MacKenzie alpine tundra      11.0
# 14   540.0                           Okanogan dry forests       5.0
# 15   548.0  Pacific Coastal Mountain icefields and tundra      11.0
# 16   551.0                                Palouse prairie       8.0
# 17   637.0                    Snake-Columbia shrub steppe      13.0
# 18   648.0                  South Central Rockies forests       5.0
# 19   777.0              Wasatch and Uinta montane forests       5.0
# 20   778.0                         Watson Highlands taiga       6.0
# 21   802.0                     Wyoming Basin shrub steppe      13.0
# 22   821.0                    Northern Cordillera forests       6.0
# 23   828.0                    Northwest Territories taiga       6.0
# 24   839.0               Northern Rockies conifer forests       5.0
#
#                                      BIOME_NAME  \
# 0                     Temperate Conifer Forests
# 1                     Temperate Conifer Forests
# 2                     Temperate Conifer Forests
# 3                                        Tundra
# 4   Temperate Grasslands, Savannas & Shrublands
# 5                     Temperate Conifer Forests
# 6                     Temperate Conifer Forests
# 7                          Boreal Forests/Taiga
# 8                                        Tundra
# 9                          Boreal Forests/Taiga
# 10  Temperate Grasslands, Savannas & Shrublands
# 11                         Boreal Forests/Taiga
# 12  Temperate Grasslands, Savannas & Shrublands
# 13                                       Tundra
# 14                    Temperate Conifer Forests
# 15                                       Tundra
# 16  Temperate Grasslands, Savannas & Shrublands
# 17                   Deserts & Xeric Shrublands
# 18                    Temperate Conifer Forests
# 19                    Temperate Conifer Forests
# 20                         Boreal Forests/Taiga
# 21                   Deserts & Xeric Shrublands
# 22                         Boreal Forests/Taiga
# 23                         Boreal Forests/Taiga
# 24                    Temperate Conifer Forests
#
#                                              geometry      c_pg    soc_pg  \
# 0   MULTIPOLYGON (((231107.227 305009.454, 226734....  0.235617  0.628577
# 1   POLYGON ((614252.395 -1139094.041, 612099.656 ...  0.141362  0.325932
# 2   POLYGON ((-166421.245 37682.88, -177859.583 32...  0.042514  0.090874
# 3   MULTIPOLYGON (((-514179.871 1392834.151, -5147...  0.007826  0.135312
# 4   MULTIPOLYGON (((725180.479 -339910.34, 723716....  0.002829  0.032326
# 5   POLYGON ((192654.361 -120678.524, 194329.256 -...  0.607495  1.697009
# 6   POLYGON ((298504.267 -341027.666, 298711.41 -3...  0.000046  0.000130
# 7   MULTIPOLYGON (((-627905.705 1421020.585, -6225...  0.001093  0.058824
# 8   MULTIPOLYGON (((-713662.418 1111909.509, -7138...  0.004798  0.026438
# 9   MULTIPOLYGON (((253378.224 142341.081, 266856....  0.048127  0.107079
# 10  MULTIPOLYGON (((761734.834 -441379.54, 761096....  0.093220  0.731455
# 11  POLYGON ((95410.16 872210.206, 96382.604 84749...  0.286204  1.399765
# 12  MULTIPOLYGON (((810422.856 -485519.04, 821381....  0.002308  0.044013
# 13  MULTIPOLYGON (((-755976.703 1182178.805, -7559...  0.460684  7.287563
# 14  MULTIPOLYGON (((474577.166 -625673.034, 473110...  0.037843  0.143096
# 15  POLYGON ((-272462.322 138751.041, -273936.73 1...  0.000536  0.002217
# 16  MULTIPOLYGON (((515405.854 -995960.586, 528108...  0.007833  0.061644
# 17  MULTIPOLYGON (((1110000.92 -1277347.136, 11039...  0.008206  0.096726
# 18  MULTIPOLYGON (((1183080.637 -911918.231, 11830...  0.744310  2.115499
# 19  POLYGON ((1121134.459 -1287486.12, 1116521.321...  0.000079  0.001014
# 20  POLYGON ((-411929.754 569605.288, -411817.914 ...  0.646094  3.343963
# 21  POLYGON ((1244350.618 -964176.711, 1247304.004...  0.012170  0.182559
# 22  POLYGON ((-356700.609 261256.416, -358733.035 ...  0.465803  2.492307
# 23  MULTIPOLYGON (((-398203.134 1369022.794, -3811...  0.047044  1.033860
# 24  POLYGON ((602690.988 -820279.059, 602996.387 -...  1.646070  6.323441
#
#        c_t_ha    soc_t_ha
# 0   51.875723  138.438498
# 1   51.002047  117.833526
# 2   95.729952  205.112782
# 3   17.801833  307.750048
# 4   21.429108  244.942044
# 5   62.469650  174.624412
# 6   59.765574  170.211475
# 7   17.724394  961.860991
# 8   45.780841  253.180004
# 9   49.877737  111.053668
# 10  14.352652  112.950052
# 11  58.659251  287.203817
# 12   6.372858  121.682259
# 13  16.801329  265.895646
# 14  58.028580  219.718776
# 15  62.051193  259.438332
# 16  15.151702  120.478506
# 17   9.112353  108.220603
# 18  49.316417  140.338805
# 19  10.673755  136.968777
# 20  39.390640  204.187256
# 21   6.112755   91.887956
# 22  35.865359  192.026795
# 23  31.138267  686.229446
# 24  64.521164  248.462573

# %%
# create vector data for biomes
biomes = eco.dissolve(by=['BIOME_ID', 'BIOME_NAME'])

# reset index columns
biomes.reset_index(inplace=True)

# drop ECO_ID and ECO_NAME columns
biomes.drop(columns=['ECO_ID', 'ECO_NAME'], inplace=True)
biomes
# Out:
#    BIOME_ID                                   BIOME_NAME  \
# 0       5.0                    Temperate Conifer Forests
# 1       6.0                         Boreal Forests/Taiga
# 2       8.0  Temperate Grasslands, Savannas & Shrublands
# 3      11.0                                       Tundra
# 4      13.0                   Deserts & Xeric Shrublands
#
#                                             geometry
# 0  MULTIPOLYGON (((860037.383 -1112586.188, 86041...
# 1  MULTIPOLYGON (((-384568.64 331052.75, -392936....
# 2  MULTIPOLYGON (((531149.592 -972252.527, 531276...
# 3  MULTIPOLYGON (((-274805.51 149096.379, -274330...
# 4  MULTIPOLYGON (((1098249.445 -1270028.854, 1096...

# %%
# add biome stats to vector data
biomes = biomes.merge(stats_biome, on='BIOME_ID')
biomes
# Out:
#    BIOME_ID                                   BIOME_NAME  \
# 0       5.0                    Temperate Conifer Forests
# 1       6.0                         Boreal Forests/Taiga
# 2       8.0  Temperate Grasslands, Savannas & Shrublands
# 3      11.0                                       Tundra
# 4      13.0                   Deserts & Xeric Shrublands
#
#                                             geometry  band  total_carbon  \
# 0  MULTIPOLYGON (((860037.383 -1112586.188, 86041...     0      3.455335
# 1  MULTIPOLYGON (((-384568.64 331052.75, -392936....     0      1.494365
# 2  MULTIPOLYGON (((531149.592 -972252.527, 531276...     0      0.106191
# 3  MULTIPOLYGON (((-274805.51 149096.379, -274330...     0      0.473845
# 4  MULTIPOLYGON (((1098249.445 -1270028.854, 1096...     0      0.020375
#
#    total_soc  avg_carbon_density  avg_soc_density
# 0  11.325572           58.816887       193.099275
# 1   8.435799           40.600871       229.473025
# 2   0.869438           14.147048       116.215565
# 3   7.451530           16.939621       266.504353
# 4   0.279285            7.046919        96.955720

# %%
# clean up vector data
biomes.drop('band', axis=1, inplace=True)
biomes.rename(columns={'total_carbon': 'c_pg',
                       'total_soc': 'soc_pg',
                       'avg_carbon_density': 'c_t_ha',
                       'avg_soc_density': 'soc_t_ha'},
              inplace=True)
biomes
# Out:
#    BIOME_ID                                   BIOME_NAME  \
# 0       5.0                    Temperate Conifer Forests
# 1       6.0                         Boreal Forests/Taiga
# 2       8.0  Temperate Grasslands, Savannas & Shrublands
# 3      11.0                                       Tundra
# 4      13.0                   Deserts & Xeric Shrublands
#
#                                             geometry      c_pg     soc_pg  \
# 0  MULTIPOLYGON (((860037.383 -1112586.188, 86041...  3.455335  11.325572
# 1  MULTIPOLYGON (((-384568.64 331052.75, -392936....  1.494365   8.435799
# 2  MULTIPOLYGON (((531149.592 -972252.527, 531276...  0.106191   0.869438
# 3  MULTIPOLYGON (((-274805.51 149096.379, -274330...  0.473845   7.451530
# 4  MULTIPOLYGON (((1098249.445 -1270028.854, 1096...  0.020375   0.279285
#
#       c_t_ha    soc_t_ha
# 0  58.816887  193.099275
# 1  40.600871  229.473025
# 2  14.147048  116.215565
# 3  16.939621  266.504353
# 4   7.046919   96.955720

# %%
# write to file
ecoregions.to_file(
    './carbon_stock_data/output_layers/ecoregions_biomes/ecoregions_carbon_stock.shp')
biomes.to_file(
    './carbon_stock_data/output_layers/ecoregions_biomes/biomes_carbon_stock.shp')

# %%
# add area to biomes table in ha
# 1 m2 = 0.0001 ha
biomes['area_ha'] = biomes.area / 10000
biomes['area_pc'] = biomes['area_ha'] / biomes['area_ha'].sum()
biomes
# Out:
#    BIOME_ID                                   BIOME_NAME  \
# 0       5.0                    Temperate Conifer Forests
# 1       6.0                         Boreal Forests/Taiga
# 2       8.0  Temperate Grasslands, Savannas & Shrublands
# 3      11.0                                       Tundra
# 4      13.0                   Deserts & Xeric Shrublands
#
#                                             geometry      c_pg     soc_pg  \
# 0  MULTIPOLYGON (((860037.383 -1112586.188, 86041...  3.455335  11.325572
# 1  MULTIPOLYGON (((-384568.64 331052.75, -392936....  1.494365   8.435799
# 2  MULTIPOLYGON (((531149.592 -972252.527, 531276...  0.106191   0.869438
# 3  MULTIPOLYGON (((-274805.51 149096.379, -274330...  0.473845   7.451530
# 4  MULTIPOLYGON (((1098249.445 -1270028.854, 1096...  0.020375   0.279285
#
#       c_t_ha    soc_t_ha       area_ha   area_pc
# 0  58.816887  193.099275  6.042429e+07  0.441091
# 1  40.600871  229.473025  3.771248e+07  0.275297
# 2  14.147048  116.215565  7.557862e+06  0.055172
# 3  16.939621  266.504353  2.838068e+07  0.207176
# 4   7.046919   96.955720  2.912918e+06  0.021264

# %%
# drop geometry
biomes_df = biomes.drop('geometry', axis=1)

# add totals row
biomes_df = pd.concat(
    [biomes_df, biomes_df.sum().to_frame().transpose()], ignore_index=True)
biomes_df
# Out:
#   BIOME_ID                                         BIOME_NAME      c_pg  \
# 0      5.0                          Temperate Conifer Forests  3.455335
# 1      6.0                               Boreal Forests/Taiga  1.494365
# 2      8.0        Temperate Grasslands, Savannas & Shrublands  0.106191
# 3     11.0                                             Tundra  0.473845
# 4     13.0                         Deserts & Xeric Shrublands  0.020375
# 5     43.0  Temperate Conifer ForestsBoreal Forests/TaigaT...  5.550111
#
#       soc_pg      c_t_ha    soc_t_ha           area_ha   area_pc
# 0  11.325572   58.816887  193.099275   60424290.322885  0.441091
# 1   8.435799   40.600871  229.473025   37712475.554948  0.275297
# 2   0.869438   14.147048  116.215565    7557862.323312  0.055172
# 3    7.45153   16.939621  266.504353   28380680.541698  0.207176
# 4   0.279285    7.046919    96.95572    2912918.176846  0.021264
# 5  28.361624  137.551346  902.247939  136988226.919689       1.0

# %%
# clean up Y2Y row names
biomes_df.loc[len(biomes_df) - 1, 'BIOME_ID'] = 0
biomes_df.loc[len(biomes_df) - 1, 'BIOME_NAME'] = 'Y2Y'

# change Y2Y rows to average for density
biomes_df.loc[len(biomes_df) - 1,
              'c_t_ha'] = biomes_df.loc[:len(biomes_df) - 2, 'c_t_ha'].mean()
biomes_df.loc[len(biomes_df) - 1,
              'soc_t_ha'] = biomes_df.loc[:len(biomes_df) - 2, 'soc_t_ha'].mean()

# get all columns except biome_name
cols = [col for col in biomes_df.columns if col != 'BIOME_NAME']

# convert to numeric
biomes_df[cols] = biomes_df[cols].apply(pd.to_numeric)

# round columns
decimals = pd.Series([1, 1, 1, 1, 1, 2], index=[
                     'c_pg', 'soc_pg', 'c_t_ha', 'soc_t_ha', 'area_ha', 'area_pc'])
biomes_df = biomes_df.round(decimals)
biomes_df
# Out:
#    BIOME_ID                                   BIOME_NAME  c_pg  soc_pg  \
# 0       5.0                    Temperate Conifer Forests   3.5    11.3
# 1       6.0                         Boreal Forests/Taiga   1.5     8.4
# 2       8.0  Temperate Grasslands, Savannas & Shrublands   0.1     0.9
# 3      11.0                                       Tundra   0.5     7.5
# 4      13.0                   Deserts & Xeric Shrublands   0.0     0.3
# 5       0.0                                          Y2Y   5.6    28.4
#
#    c_t_ha  soc_t_ha      area_ha  area_pc
# 0    58.8     193.1   60424290.3     0.44
# 1    40.6     229.5   37712475.6     0.28
# 2    14.1     116.2    7557862.3     0.06
# 3    16.9     266.5   28380680.5     0.21
# 4     7.0      97.0    2912918.2     0.02
# 5    27.5     180.5  136988226.9     1.00

# %%
# export to csv
biomes_df.to_csv(
    './carbon_stock_data/output_layers/biomes_carbon_stocks.csv', index=False)
